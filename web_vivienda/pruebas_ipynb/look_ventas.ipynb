# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta_del_archivo = 'data/ventas_web.xlsx'

# Lee el archivo xlsx y carga los datos en un DataFrame
#instalar = pip install openpyxl
df = pd.read_excel(ruta_del_archivo)

# %%
df.head(5)
# Out:
#    Column1     Tipo_vivienda                           Direccion  \
# 0        0              Piso                    calle del Aguado
# 1        1              Piso        calle de las Procesiones, 31
# 2        2  Casa unifamiliar                 calle de Degaña, 19
# 3        3              Piso  calle del Referéndum de Viñagrande
# 4        4              Piso                 Paseo de la Cárcava
#
#                                  Barrio     Distrito    Población    Precio  \
# 0        Hispanoamérica-Las Comunidades    Valdemoro    Valdemoro  215000.0
# 1                                Centro    Galapagar    Galapagar  140000.0
# 2                           Villalbilla  Villalbilla  Villalbilla  279000.0
# 3  Valderas-Los Castillos-Parque Lisboa     Alcorcón     Alcorcón  196800.0
# 4                                Griñón       Griñón       Griñón  130000.0
#
#    Superficie Habitaciones    Baños    Precio/m²
# 0       122.0      3 habs.  2 baños  1762.295082
# ...

# %%
df["Precio/m²"] = df["Precio/m²"].round(2)

# %%
df.head(5)
# Out:
#    Column1     Tipo_vivienda                           Direccion  \
# 0        0              Piso                    calle del Aguado
# 1        1              Piso        calle de las Procesiones, 31
# 2        2  Casa unifamiliar                 calle de Degaña, 19
# 3        3              Piso  calle del Referéndum de Viñagrande
# 4        4              Piso                 Paseo de la Cárcava
#
#                                  Barrio     Distrito    Población    Precio  \
# 0        Hispanoamérica-Las Comunidades    Valdemoro    Valdemoro  215000.0
# 1                                Centro    Galapagar    Galapagar  140000.0
# 2                           Villalbilla  Villalbilla  Villalbilla  279000.0
# 3  Valderas-Los Castillos-Parque Lisboa     Alcorcón     Alcorcón  196800.0
# 4                                Griñón       Griñón       Griñón  130000.0
#
#    Superficie Habitaciones    Baños  Precio/m²
# 0       122.0      3 habs.  2 baños    1762.30
# ...

# %%
df.drop('Column1', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#       Tipo_vivienda                           Direccion  \
# 0              Piso                    calle del Aguado
# 1              Piso        calle de las Procesiones, 31
# 2  Casa unifamiliar                 calle de Degaña, 19
# 3              Piso  calle del Referéndum de Viñagrande
# 4              Piso                 Paseo de la Cárcava
#
#                                  Barrio     Distrito    Población  Precio  \
# 0        Hispanoamérica-Las Comunidades    Valdemoro    Valdemoro  215000
# 1                                Centro    Galapagar    Galapagar  140000
# 2                           Villalbilla  Villalbilla  Villalbilla  279000
# 3  Valderas-Los Castillos-Parque Lisboa     Alcorcón     Alcorcón  196800
# 4                                Griñón       Griñón       Griñón  130000
#
#    Superficie Habitaciones    Baños  Precio/m²
# 0       122.0      3 habs.  2 baños    1762.30
# 1        66.0      2 habs.   1 baño    2121.21
# ...

# %%
df_final = "viviendas_web_ventas.xlsx"

# Guardar el DataFrame como un archivo CSV
df.to_excel(df_final, index=False)

# %% [markdown]
# ### Lectura de nuevo df ventas

# %%
ruta_del_archivo = 'data/viviendas_web_ventas.xlsx'

# Lee el archivo xlsx y carga los datos en un DataFrame
#instalar = pip install openpyxl
df = pd.read_excel(ruta_del_archivo)

# %%
df.head(5)
# Out:
#       Tipo_vivienda                           Direccion  \
# 0              Piso                    calle del Aguado
# 1              Piso        calle de las Procesiones, 31
# 2  Casa unifamiliar                 calle de Degaña, 19
# 3              Piso  calle del Referéndum de Viñagrande
# 4              Piso                 Paseo de la Cárcava
#
#                                  Barrio     Distrito    Población  Precio  \
# 0        Hispanoamérica-Las Comunidades    Valdemoro    Valdemoro  215000
# 1                                Centro    Galapagar    Galapagar  140000
# 2                           Villalbilla  Villalbilla  Villalbilla  279000
# 3  Valderas-Los Castillos-Parque Lisboa     Alcorcón     Alcorcón  196800
# 4                                Griñón       Griñón       Griñón  130000
#
#    Superficie Habitaciones    Baños  Precio/m²
# 0       122.0      3 habs.  2 baños    1762.30
# 1        66.0      2 habs.   1 baño    2121.21
# ...

# %%
df.dtypes
# Out:
# Tipo_vivienda     object
# Direccion         object
# Barrio            object
# Distrito          object
# Población         object
# Precio             int64
# Superficie       float64
# Habitaciones      object
# Baños             object
# Precio/m²        float64
# dtype: object
